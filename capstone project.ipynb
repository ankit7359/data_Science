# %% [markdown]
# # Capstone Project - Python

# %% [markdown]
# Part - 1 - This project is for understanding the role of python in the world of Data Science

# %%
import numpy as np
import pandas as pd
print("Capstone Project - Python")
# Out:
# Capstone Project - Python
